# %% [markdown]
# <a href="https://colab.research.google.com/github/rogerpanel/CV/blob/main/Transformer_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Define the generator and discriminator architectures
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        # Define your generator architecture

    def forward(self, input):
        # Implement the forward pass of the generator
        return output

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        # Define your discriminator architecture

    def forward(self, input):
        # Implement the forward pass of the discriminator
        return output

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Training parameters
batch_size = 64
num_epochs = 100
learning_rate = 0.0002

# Load the stego audio images
stego_audio_images = np.load('/content/image_npy_1.npy')

# Normalize the stego audio images
stego_audio_images = (stego_audio_images - np.min(stego_audio_images)) / (np.max(stego_audio_images) - np.min(stego_audio_images))

# Convert stego audio images to torch tensor
stego_audio_images_tensor = torch.from_numpy(stego_audio_images).to(device)

# Create the generator and discriminator instances
generator = Generator().to(device)
discriminator = Discriminator().to(device)

# Define the loss functions
criterion = nn.BCELoss()

# Define the optimizers for generator and discriminator
optimizer_G = optim.Adam(generator.parameters(), lr=learning_rate)
optimizer_D = optim.Adam(discriminator.parameters(), lr=learning_rate)

# Training loop
for epoch in range(num_epochs):
    for i in range(0, len(stego_audio_images), batch_size):
        # Sample a batch of stego audio images
        batch = stego_audio_images_tensor[i:i+batch_size]

        # Create the labels for real and fake audio samples
        real_labels = torch.ones(batch.size(0), 1).to(device)
        fake_labels = torch.zeros(batch.size(0), 1).to(device)

        # Train the generator
        optimizer_G.zero_grad()

        # Generate fake audio samples
        fake_samples = generator(batch)

        # Compute the generator loss
        generator_loss = criterion(discriminator(fake_samples), real_labels)

        # Update the generator
        generator_loss.backward()
        optimizer_G.step()

        # Train the discriminator
        optimizer_D.zero_grad()

        # Compute the discriminator loss for real audio samples
        real_loss = criterion(discriminator(batch), real_labels)

        # Compute the discriminator loss for fake audio samples
        fake_loss = criterion(discriminator(fake_samples.detach()), fake_labels)

        # Compute the total discriminator loss
        discriminator_loss = (real_loss + fake_loss) / 2

        # Update the discriminator
        discriminator_loss.backward()
        optimizer_D.step()

    # Print the losses for monitoring
    print(f"Epoch [{epoch+1}/{num_epochs}] Generator Loss: {generator_loss.item():.4f} Discriminator Loss: {discriminator_loss.item():.4f}")

# Generate audio samples using the trained generator
num_samples = 10
random_inputs = torch.randn(num_samples, latent_dim).to(device)
generated_samples = generator(random_inputs).detach().cpu().numpy()

# Inverse spectrogram transformation for the generated audio
reconstructed_audio = []
for i in range(num_samples):
    generated_spec = generated_samples[i]

    # Inverse spectrogram transformation
    generated_audio = librosa.griffinlim(generated_spec)

    reconstructed_audio.append(generated_audio)

# Evaluate the quality and accuracy of the extracted audio
for i in range(num_samples):
    generated_audio = reconstructed_audio[i]

    # Evaluate the quality and accuracy of the generated audio
    mse = np.mean((original_audio - generated_audio) ** 2)
    psnr = 20 * np.log10(np.max(original_audio) / np.sqrt(mse))
    ssim = librosa.core.ssim(original_audio, generated_audio)

    print(f"Sample {i+1}: MSE: {mse:.4f}, PSNR: {psnr:.2f} dB, SSIM: {ssim:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-b7382519bc4b> in <cell line: 53>()
#      51
#      52 # Define the optimizers for generator and discriminator
# ---> 53 optimizer_G = optim.Adam(generator.parameters(), lr=learning_rate)
#      54 optimizer_D = optim.Adam(discriminator.parameters(), lr=learning_rate)
#      55
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adam.py in __init__(self, params, lr, betas, eps, weight_decay, amsgrad, foreach, maximize, capturable, differentiable, fused)
#      31                         maximize=maximize, foreach=foreach, capturable=capturable,
#      32                         differentiable=differentiable, fused=fused)
# ---> 33         super().__init__(params, defaults)
#      34
#      35         if fused:
#
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Define the generator and discriminator architectures
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        # Define your generator architecture
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = 1, kernel_size = (5,5), stride = 2, padding = 2)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(in_channels = 3, out_channels = 3, kernel_size = (5, 5), stride = 2, padding = 2)
        self.relu2 = nn.ReLU()
        # Add more convolutional layers as needed

    def forward(self, input):
        # Implement the forward pass of the generator
        x = self.conv1(input)
        x = self.relu1(x)
        x = self.conv2(x)
        x = self.relu2(x)
        # Add more convolutional layers and operations as needed
        return x

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = 1, kernel_size = (3, 3), stride = 1, padding = 1)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(in_channels = 1, out_channels = 1, kernel_size = (3, 3), stride = 1, padding = 1)
        self.relu2 = nn.ReLU()
        # Add more convolutional layers as needed

    def forward(self, input):
        x = self.conv1(input)
        x = self.relu1(x)
        x = self.conv2(x)
        x = self.relu2(x)
        # Add more convolutional layers and operations as needed
        return x


# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Training parameters
batch_size = 64
num_epochs = 100
learning_rate = 0.0002

# Load the stego audio images
stego_audio_images = np.load('/content/image_npy_1.npy')

# Normalize the stego audio images
stego_audio_images = (stego_audio_images - np.min(stego_audio_images)) / (np.max(stego_audio_images) - np.min(stego_audio_images))

# Convert stego audio images to torch tensor
stego_audio_images_tensor = torch.from_numpy(stego_audio_images).to(device)

# Create the generator and discriminator instances
generator = Generator().to(device)
discriminator = Discriminator().to(device)

# Define the loss functions
criterion = nn.BCELoss()

# Define the optimizers for generator and discriminator
optimizer_G = optim.Adam(generator.parameters(), lr=learning_rate)
optimizer_D = optim.Adam(discriminator.parameters(), lr=learning_rate)

# Training loop
for epoch in range(num_epochs):
    for i in range(0, len(stego_audio_images), batch_size):
        # Sample a batch of stego audio images
        batch = stego_audio_images_tensor[i:i+batch_size]

        # Create the labels for real and fake audio samples
        real_labels = torch.ones(batch.size(0), 1).to(device)
        fake_labels = torch.zeros(batch.size(0), 1).to(device)

        # Train the generator
        optimizer_G.zero_grad()

        # Generate fake audio samples
        fake_samples = generator(batch.float())


        # Compute the generator loss
        generator_loss = criterion(discriminator(fake_samples), real_labels)

        # Update the generator
        generator_loss.backward()
        optimizer_G.step()

        # Train the discriminator
        optimizer_D.zero_grad()

        # Compute the discriminator loss for real audio samples
        real_loss = criterion(discriminator(batch), real_labels)

        # Compute the discriminator loss for fake audio samples
        fake_loss = criterion(discriminator(fake_samples.detach()), fake_labels)

        # Compute the total discriminator loss
        discriminator_loss = (real_loss + fake_loss) / 2

        # Update the discriminator
        discriminator_loss.backward()
        optimizer_D.step()

    # Print the losses for monitoring
    print(f"Epoch [{epoch+1}/{num_epochs}] Generator Loss: {generator_loss.item():.4f} Discriminator Loss: {discriminator_loss.item():.4f}")

# Generate audio samples using the trained generator
num_samples = 10
random_inputs = torch.randn(num_samples, latent_dim).to(device)
generated_samples = generator(random_inputs).detach().cpu().numpy()

# Inverse spectrogram transformation for the generated audio
reconstructed_audio = []
for i in range(num_samples):
    generated_spec = generated_samples[i]

    # Inverse spectrogram transformation
    generated_audio = librosa.griffinlim(generated_spec)

    reconstructed_audio.append(generated_audio)

# Evaluate the quality and accuracy of the extracted audio
for i in range(num_samples):
    generated_audio = reconstructed_audio[i]

    # Evaluate the quality and accuracy of the generated audio
    mse = np.mean((original_audio - generated_audio) ** 2)
    psnr = 20 * np.log10(np.max(original_audio) / np.sqrt(mse))
    ssim = librosa.core.ssim(original_audio, generated_audio)

    print(f"Sample {i+1}: MSE: {mse:.4f}, PSNR: {psnr:.2f} dB, SSIM: {ssim:.4f}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-f9333551b411> in <cell line: 76>()
#      87
#      88         # Generate fake audio samples
# ---> 89         fake_samples = generator(batch.float())
#      90
#      91
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-12-f9333551b411> in forward(self, input)
#      20     def forward(self, input):
#      21         # Implement the forward pass of the generator
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Define the generator and discriminator architectures

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        # Define your generator architecture
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=64, kernel_size=(5, 5), stride=2, padding=2)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=(5, 5), stride=2, padding=2)
        self.relu2 = nn.ReLU()
        # Add more convolutional layers as needed

    def forward(self, input):
        # Implement the forward pass of the generator
        x = self.conv1(input)
        x = self.relu1(x)
        x = self.conv2(x)
        x = self.relu2(x)
        # Add more convolutional layers and operations as needed
        return x



class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=64, kernel_size=(3, 3), stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=(3, 3), stride=1, padding=1)
        self.relu2 = nn.ReLU()
        # Add more convolutional layers as needed

    def forward(self, input):
        x = self.conv1(input)
        x = self.relu1(x)
        x = self.conv2(x)
        x = self.relu2(x)
        # Add more convolutional layers and operations as needed
        return x


# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Training parameters
batch_size = 64
num_epochs = 100
learning_rate = 0.0002
latent_dim = 100  # Dimensionality of the input noise vector

# Load the stego audio images
stego_audio_images = np.load('/content/image_npy_1.npy')

# Normalize the stego audio images
stego_audio_images = (stego_audio_images - np.min(stego_audio_images)) / (np.max(stego_audio_images) - np.min(stego_audio_images))

# Convert stego audio images to torch tensor
stego_audio_images_tensor = torch.from_numpy(stego_audio_images).to(device)

# Create the generator and discriminator instances
generator = Generator().to(device)
discriminator = Discriminator().to(device)

# Define the loss functions
criterion = nn.BCELoss()

# Define the optimizers for generator and discriminator
optimizer_G = optim.Adam(generator.parameters(), lr=learning_rate)
optimizer_D = optim.Adam(discriminator.parameters(), lr=learning_rate)

# Training loop
for epoch in range(num_epochs):
    for i in range(0, len(stego_audio_images), batch_size):
        # Sample a batch of stego audio images
        batch = stego_audio_images_tensor[i:i+batch_size]

        # Create the labels for real and fake audio samples
        real_labels = torch.ones(batch.size(0), 1).to(device)
        fake_labels = torch.zeros(batch.size(0), 1).to(device)

        # Train the generator
        optimizer_G.zero_grad()

        # Generate fake audio samples
        fake_samples = generator(batch.float())

        # Add an extra dimension to the fake_samples tensor
        fake_samples = fake_samples.unsqueeze(2)

        # Resize the output of the discriminator
        resized_fake_samples = nn.functional.interpolate(fake_samples, size=(1, 1))

        # Compute the generator loss
        generator_loss = criterion(discriminator(resized_fake_samples), real_labels)

        # Update the generator
        generator_loss.backward()
        optimizer_G.step()

        # Train the discriminator
        optimizer_D.zero_grad()

        # Compute the discriminator loss for real audio samples
        real_loss = criterion(discriminator(batch), real_labels)

        # Compute the discriminator loss for fake audio samples
        fake_loss = criterion(discriminator(resized_fake_samples.detach()), fake_labels)

        # Compute the total discriminator loss
        discriminator_loss = (real_loss + fake_loss) / 2

        # Update the discriminator
        discriminator_loss.backward()
        optimizer_D.step()

    # Print the losses for monitoring
    print(f"Epoch [{epoch+1}/{num_epochs}] Generator Loss: {generator_loss.item():.4f} Discriminator Loss: {discriminator_loss.item():.4f}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-22-650fd6828b45> in <cell line: 80>()
#      91
#      92         # Generate fake audio samples
# ---> 93         fake_samples = generator(batch.float())
#      94
#      95         # Add an extra dimension to the fake_samples tensor
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-22-650fd6828b45> in forward(self, input)
#      21     def forward(self, input):
# ...
